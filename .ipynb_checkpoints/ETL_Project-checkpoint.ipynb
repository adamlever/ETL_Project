# %% [markdown]
# ### ETL Project

# %%
import os
import csv
import pandas as pd

# %%
Total_final_renewable_energy_consumption_df = pd.read_csv('Total_Final_Renewable_energy_consumption_clean.csv')
Total_final_renewable_energy_consumption_df.columns.values[0] = "Country Name"
Total_final_renewable_energy_consumption_df.head()
# Out:
#   Country Name Product                            Flow  NoProduct  \
# 0    Australia   Total  Total final consumption (ktoe)  11. Total
# 1      Austria   Total  Total final consumption (ktoe)  11. Total
# 2      Belgium   Total  Total final consumption (ktoe)  11. Total
# 3       Canada   Total  Total final consumption (ktoe)  11. Total
# 4        Chile   Total  Total final consumption (ktoe)  11. Total
#
#                                NoFlow    1990    1991    1992    1993    1994  \
# 0  07. Total final consumption (ktoe)   56656   56215   56737   58833   60166
# 1  07. Total final consumption (ktoe)   19767   21259   20712   20969   20400
# 2  07. Total final consumption (ktoe)   32223   34113   34501   34090   37122
# 3  07. Total final consumption (ktoe)  158461  157299  160191  164201  170262
# 4  07. Total final consumption (ktoe)   11099   11800   13115   13436   14275
#
#    ...    2006    2007    2008    2009    2010    2011    2012    2013  \
# ...

# %%
Renewable_energy_consumption_clean_df = pd.read_csv('Renewable_energy_consumption_clean.csv')
Renewable_energy_consumption_clean_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  \
# 0  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 1  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 2  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 3  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 4  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
#
#         1990       1991       1992       1993       1994       1995  ...  \
# 0   0.268747   0.234955   0.238778   0.195134   0.183241   0.173372  ...
# 1  15.924532  17.036444  26.521629  30.585667  32.796251  35.075640  ...
# 2  72.255252  71.888639  72.723283  71.277056  72.220269  73.945888  ...
# 3  25.518088  32.998174  46.813329  51.152042  51.459544  50.609710  ...
# ...

# %%
GDP_df = pd.read_csv('GDP_clean.csv')
GDP_df.head()
# Out:
#   Country Name Country Code     Indicator Name          1990          1991  \
# 0        Aruba          ABW  GDP (current US$)  7.648871e+08  8.721387e+08
# 1  Afghanistan          AFG  GDP (current US$)           NaN           NaN
# 2       Angola          AGO  GDP (current US$)  1.122876e+10  1.060378e+10
# 3      Albania          ALB  GDP (current US$)  2.028554e+09  1.099559e+09
# 4      Andorra          AND  GDP (current US$)  1.029048e+09  1.106929e+09
#
#            1992          1993          1994          1995          1996  ...  \
# 0  9.584632e+08  1.082980e+09  1.245688e+09  1.320475e+09  1.379961e+09  ...
# 1           NaN           NaN           NaN           NaN           NaN  ...
# 2  8.307811e+09  5.768720e+09  4.438321e+09  5.538749e+09  7.526447e+09  ...
# 3  6.521750e+08  1.185315e+09  1.880952e+09  2.392765e+09  3.199643e+09  ...
# 4  1.210014e+09  1.007026e+09  1.017549e+09  1.178739e+09  1.223945e+09  ...
#
# ...

# %%
# Merge two dataframes using an inner join
merge_df = pd.merge(Total_final_renewable_energy_consumption_df, Renewable_energy_consumption_clean_df, on="Country Name")
merge_df
# Out:
#        Country Name Product                            Flow  NoProduct  \
# 0         Australia   Total  Total final consumption (ktoe)  11. Total
# 1           Austria   Total  Total final consumption (ktoe)  11. Total
# 2           Belgium   Total  Total final consumption (ktoe)  11. Total
# 3            Canada   Total  Total final consumption (ktoe)  11. Total
# 4             Chile   Total  Total final consumption (ktoe)  11. Total
# 5    Czech Republic   Total  Total final consumption (ktoe)  11. Total
# 6           Denmark   Total  Total final consumption (ktoe)  11. Total
# 7           Estonia   Total  Total final consumption (ktoe)  11. Total
# 8           Finland   Total  Total final consumption (ktoe)  11. Total
# 9            France   Total  Total final consumption (ktoe)  11. Total
# 10          Germany   Total  Total final consumption (ktoe)  11. Total
# 11           Greece   Total  Total final consumption (ktoe)  11. Total
# ...
